# %%
import cv2
import numpy as np

# %%
cv2.imread("myphoto.jpg")
# Out:
# array([[[36, 35, 37],
#         [36, 35, 37],
#         [36, 35, 37],
#         ...,
#         [ 0, 62, 42],
#         [ 7, 79, 57],
#         [21, 93, 71]],
#
#        [[34, 33, 35],
#         [35, 34, 36],
#         [36, 35, 37],
#         ...,
#         [ 0, 61, 39],
#         [ 0, 62, 41],
#         [ 5, 75, 52]],
#
#        [[35, 34, 36],
#         [38, 37, 39],
#         [40, 39, 41],
#         ...,
#         [ 0, 72, 48],
#         [ 0, 56, 33],
#         [ 0, 59, 34]],
#
#        ...,
#
#        [[70, 87, 96],
#         [71, 88, 97],
#         [72, 89, 98],
#         ...,
#         [49, 48, 50],
#         [31, 40, 53],
#         [14, 29, 45]],
#
#        [[68, 85, 94],
#         [69, 86, 95],
#         [70, 87, 96],
#         ...,
#         [49, 48, 50],
#         [31, 40, 53],
#         [13, 28, 44]],
#
#        [[67, 84, 93],
#         [68, 85, 94],
#         [69, 86, 95],
#         ...,
#         [49, 48, 50],
#         [31, 40, 53],
#         [13, 28, 44]]], dtype=uint8)

# %%
point = image[50, 500]
point = [255, 255, 255]
print(point)
